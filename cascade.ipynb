# %%
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img=cv2.imread("image_01.png",cv2.IMREAD_GRAYSCALE)
gls=cv2.imread("image_02.png",cv2.IMREAD_GRAYSCALE)
grp=cv2.imread("image_03.png",cv2.IMREAD_GRAYSCALE)

# %%
size = (600,600)
imgr = cv2.resize(img, size)
glsr = cv2.resize(gls, size)
grpr= cv2.resize(grp, size)

# %%
plt.figure(figsize=(25,20))
plt.subplot(142);plt.imshow(imgr,cmap='gray');plt.title("Normal Image")
plt.subplot(143);plt.imshow(glsr,cmap='gray');plt.title("Glass Image")
plt.subplot(144);plt.imshow(grpr,cmap='gray');plt.title("Group Image");
plt.show()

# %%
face_cas=cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

# %%
def detect(im):
    face=im.copy()
    rect=face_cas.detectMultiScale(face)

    for (x,y,w,h) in rect:
        cv2.rectangle(face,(x,y) , (x+w,y+h) , (255,255,255) , 10)
    return face

# %%
res_img=detect(img)
plt.imshow(res_img,cmap='gray')
plt.show()

# %%
res_gls=detect(gls)
plt.imshow(res_gls,cmap='gray')
plt.show()

# %%
res_grp=detect(grp)
plt.imshow(res_grp,cmap='gray')
plt.show()

# %%
eye_cas=cv2.CascadeClassifier('haarcascade_eye.xml')

# %%
def detect_eye(im):
    face=im.copy()
    rect=eye_cas.detectMultiScale(face)

    for (x,y,w,h) in rect:
        cv2.rectangle(face,(x,y) , (x+w,y+h) , (255,255,255) , 10)
    
    return face

# %%
res_img=detect_eye(img)
plt.imshow(res_img,cmap='gray')
plt.show()

# %%
res_img=detect_eye(gls)
plt.imshow(res_img,cmap='gray')
plt.show()

# %%
res_grp=detect_eye(grp)
plt.imshow(res_grp,cmap='gray')
plt.show()

# %%
cap=cv2.VideoCapture(0)

plt.ion()
fig,ax=plt.subplots()
rect,frame=cap.read(0)
frame=detect(frame)
im=ax.imshow(cv2.cvtColor(frame,cv2.COLOR_BGR2RGB))
plt.title('Video Face Detection')

while True:
    rect,frmae=cap.read(0)
    frame=detect(frame)

    im.set_data(cv2.cvtColor(frame,cv2.COLOR_BGR2RGB))
    plt.pause(0.10)

cap.relese()
plt.close()
